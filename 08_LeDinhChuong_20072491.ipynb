# %% [markdown]
# # Bài Test1
# Môn Python
# Số TT:     08
# Họ và tên:  Lê Đình Chương
# MSSV     20072491
# Lớp     DHKHMT16A
# Ngày thi:11/3/2022
# Thời gian: 60 phút
#
# ---

# %% [markdown]
# ## Bài 1. Viết chương trình nhập vào một mảng N số nguyên dương. In ra các số chẵn (nếu có), nếu không có số chẵn nào in ra "NONE"

# %%
### START CODE HERE ### 
import numpy as np 
n = int(input("Nhap n: "))
sochan = False
arr = np.random.randint(0, 10, size= n)
inarr = []
for i in range(arr.size):
    if arr[i] % 2 == 0:
        sochan = True
        inarr.append(arr[i])
if(not(sochan)):
    print("NONE")
else:
    print(inarr)
### END CODE HERE ###
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-5fb12907b34d> in <module>
#       1 ### START CODE HERE ###
#       2 import numpy as np
# ----> 3 n = int(input("Nhap n: "))
#       4 sochan = False
#       5 arr = np.random.randint(0, 10, size= n)
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ## Bài 2: Viết chương trình kiểm tra một năm có phải năm nhuận không.
#
# Năm nhuận là năm chia hết cho 4, trừ những năm đầu thế kỷ (chia hết cho 100). Những năm đầu thế kỷ là năm nhuận khi nó chia hết cho 400 (ví dụ năm 2100 không phải là năm nhuận, 2104 là năm nhuận).

# %%
### START CODE HERE ### 
nam = int(input("nhap nam: "))
if(nam % 400 == 0) or ((nam % 4 == 0) and (nam % 100 != 0)):
    print("Nam Nhuan")
else:
    print("Khong phai nam nhuan")

### END CODE HERE ###
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-23e4887c786b> in <module>
#       1 ### START CODE HERE ###
# ----> 2 nam = int(input("nhap nam: "))
#       3 if(nam % 400 == 0) or ((nam % 4 == 0) and (nam % 100 != 0)):
#       4     print("Nam Nhuan")
#       5 else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
# ...

# %% [markdown]
# ## Bài 3: Cho một ma trận A bất kỳ. Trong mỗi hàng, ta định nghĩa độ biến động của nó là sự khác nhau giữa giá trị lớn nhất và nhỏ nhất của các phần tử trong hàng đó. Hãy viết hàm myfunc trả về tổng độ biến động của tất cả các hàng trong ma trận đó.A = np.array([[1., 2, 3, 2], [4, 3, 7, 4], [1, 4, 2, 3]]). Ví dụ với ma trận A trong bài học, độ biến động của mỗi hàng lần lượt là 2.0, 4.0, 3.0. Vậy myfunc(A) = 9.0.

# %%
### START CODE HERE ### 
import numpy as np
def myfunc(A):
    TBienDong = 0
    for i in range(A.shape[0]):
         TBienDong += A[i, :].max() -A[i, :].min()
    return TBienDong
MatranA = np.random.randint(0, 10, size =(4,4))
print(MatranA)
print("Tong bien dong cua tat ca cac hang matran A: " + str(myfunc(MatranA)))
### END CODE HERE ###
# Out:
# [[8 9 1 0]
#  [1 2 8 6]
#  [6 4 2 8]
#  [7 2 7 1]]
# Tong bien dong cua tat ca cac hang matran A: 28

# %% [markdown]
# ## Bài 4: Giả sử tập dữ liệu bao gồm nhiều điểm dữ liệu có cùng chiều, được sắp xếp thành một mảng hai chiều mô tả một ma trận - được gọi là ma trận dữ liệu. Mỗi hàng của ma trận này là một điểm dữ liệu. Một trong các kỹ thuật quan trọng trước khi áp dụng các thuật toán Machine Learning lên dữ liệu là chuẩn hoá dữ liệu. Trong các phương pháp chuẩn hoá dữ liệu, một phương pháp thường được sử dụng là đưa dữ liệu về dạng zero-mean, tức trung bình cộng của toàn bộ dữ liệu là một vector có toàn bộ các thành phần bằng 0.Cách chuẩn hoá này có thể được thực hiện bằng cách trước tiên tính vector trung bình của toàn bộ dữ liệu (ở đây là vector trung bình của toàn bộ các hàng), sau đó lấy từng điểm dữ liệu trừ đi vector trung bình. Khi đó, ma trận mới sẽ có trung bình cộng các hàng bằng vector 0, và ta nói rằng ma trận dữ liệu mới này là zero-mean. Cho một mảng hai chiều X mô tả dữ liệu, trong đó X[i] là một mảng một chiều mô tả dữ liệu có chỉ số i. Hãy viết hàm zero_mean trả về ma trận dữ liệu đã chuẩn hoá theo zero-mean.

# %%
### START CODE HERE ### 
import numpy as np
def zero_mean(data):
    return data - np.mean(data, 0)
rd = np.random.randint(0, 10,size=(4,4))
print(rd)
zero_meanrd = zero_mean(rd)
print(zero_meanrd)

    


### END CODE HERE ###
# Out:
# [[9 6 6 7]
#  [5 9 3 6]
#  [0 0 3 1]
#  [3 9 4 1]]
# [[ 4.75  0.    2.    3.25]
#  [ 0.75  3.   -1.    2.25]
#  [-4.25 -6.   -1.   -2.75]
#  [-1.25  3.    0.   -2.75]]

# %% [markdown]
# ## Bài 5: Hãy lập trình hàm softmax.
#
# Gợi ý: Sử dụng hàm np.exp().
# ![image.png](attachment:image.png)

# %%
### START CODE HERE ### 
import numpy as np 

def softmax(Z):
    exp_Z = np.exp(Z)
    A = exp_Z / exp_Z.sum(axis = 0)
    return A

### END CODE HERE ###
